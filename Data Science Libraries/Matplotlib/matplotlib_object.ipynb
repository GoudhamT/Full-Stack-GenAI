# %%
import matplotlib.pyplot  as plt
import pandas as pd
import numpy as np

# %%
x = [1,2,3,4,5]
y = [10,5,2,6,3]

# %%
plt.scatter(x,y)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1]) # rect shape - left, bottom, width, height
ax.plot(x,y)

# %%
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 ax.plot(x,y)
# ----> 2 ax.show()
#
# AttributeError: 'Axes' object has no attribute 'show'
