# %%
import pandas as pd

# %%
pd.DataFrame([1,2,3])
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
pd.DataFrame([1,2,3],columns = ["goudham"])
# Out:
#    goudham
# 0        1
# 1        2
# 2        3

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.loc[0:5,['Pclass','Ticket','Name']]
# Out:
#    Pclass            Ticket                                               Name
# 0       3         A/5 21171                            Braund, Mr. Owen Harris
# 1       1          PC 17599  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       3  STON/O2. 3101282                             Heikkinen, Miss. Laina
# 3       1            113803       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       3            373450                           Allen, Mr. William Henry
# 5       3            330877                                   Moran, Mr. James

# %%
titanic.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# ...

# %%
titanic.loc[titanic['Cabin'].notnull()]
# Out:
#                                                   Name        Cabin
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          C85
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         C123
# 6                              McCarthy, Mr. Timothy J          E46
# 10                     Sandstrom, Miss. Marguerite Rut           G6
# 11                            Bonnell, Miss. Elizabeth         C103
# ..                                                 ...          ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          D35
# 872                           Carlsson, Mr. Frans Olof  B51 B53 B55
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          C50
# 887                       Graham, Miss. Margaret Edith          B42
# 889                              Behr, Mr. Karl Howell         C148
#
# [204 rows x 2 columns]

# %%
titanic.loc[titanic['Cabin'].notnull(),['Name','Cabin']]
# Out:
#                                                   Name        Cabin
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...          C85
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         C123
# 6                              McCarthy, Mr. Timothy J          E46
# 10                     Sandstrom, Miss. Marguerite Rut           G6
# 11                            Bonnell, Miss. Elizabeth         C103
# ..                                                 ...          ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)          D35
# 872                           Carlsson, Mr. Frans Olof  B51 B53 B55
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)          C50
# 887                       Graham, Miss. Margaret Edith          B42
# 889                              Behr, Mr. Karl Howell         C148
#
# [204 rows x 2 columns]

# %% [markdown]
# # Methods in Pandas

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
def append_name(name):
    return 'Sir / Mam ' + name

# %%
titanic['Name'].apply(append_name)
# Out:
# 0                      Sir / Mam Braund, Mr. Owen Harris
# 1      Sir / Mam Cumings, Mrs. John Bradley (Florence...
# 2                       Sir / Mam Heikkinen, Miss. Laina
# 3      Sir / Mam Futrelle, Mrs. Jacques Heath (Lily M...
# 4                     Sir / Mam Allen, Mr. William Henry
#                              ...
# 886                      Sir / Mam Montvila, Rev. Juozas
# 887               Sir / Mam Graham, Miss. Margaret Edith
# 888    Sir / Mam Johnston, Miss. Catherine Helen "Car...
# 889                      Sir / Mam Behr, Mr. Karl Howell
# 890                        Sir / Mam Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
titanic.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
titanic['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# append id depreciated , you can use concatenation

# %%
row0 = titanic.loc[0]

# %%
row0
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
pd.DataFrame(row0)
# Out:
#                                    0
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S

# %%
row0 = pd.DataFrame(row0).T

# %%
row0
# Out:
#   PassengerId Survived Pclass                     Name   Sex   Age SibSp  \
# 0           1        0      3  Braund, Mr. Owen Harris  male  22.0     1
#
#   Parch     Ticket  Fare Cabin Embarked
# 0     0  A/5 21171  7.25   NaN        S

# %%
titanic= pd.concat([titanic,row0])

# %%
titanic.tail(5)
# Out:
#     PassengerId Survived Pclass                                      Name  \
# 887         888        1      1              Graham, Miss. Margaret Edith
# 888         889        0      3  Johnston, Miss. Catherine Helen "Carrie"
# 889         890        1      1                     Behr, Mr. Karl Howell
# 890         891        0      3                       Dooley, Mr. Patrick
# 0             1        0      3                   Braund, Mr. Owen Harris
#
#         Sex   Age SibSp Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0     0     0      112053   30.0   B42        S
# 888  female   NaN     1     2  W./C. 6607  23.45   NaN        S
# 889    male  26.0     0     0      111369   30.0  C148        C
# 890    male  32.0     0     0      370376   7.75   NaN        Q
# 0      male  22.0     1     0   A/5 21171   7.25   NaN        S

# %%
titanic.drop_duplicates()
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 886         887        0      2
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                             Allen, Mr. William Henry    male  35.0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
df = pd.DataFrame([[1,2,3],[4,5,6]], columns=['a','b','c'])

# %%
df.mean(axis=1)
# Out:
# 0    2.0
# 1    5.0
# dtype: float64

# %%
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
titanic.groupby('Age').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %% [markdown]
# # series in Pandas

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1,2,3],name='test')
# Out:
# 0    1
# 1    2
# 2    3
# Name: test, dtype: int64

# %%
s1 = pd.Series([1,2,3],name='test',index=['i1','i2','i3'])

# %%
s1[0]
# Out:
# C:\Users\goudh\AppData\Local\Temp\ipykernel_14164\643609873.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]
# 1

# %%
s1.iloc[0]
# Out:
# 1

# %%
s1.loc['test']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'test'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 s1.loc['test']
#
# ...

# %%
titanic.head(1).T
# Out:
#                                    0
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S

# %%
# t1 = pd.Series(titanic[0])
titanic[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[179], line 2
#       1 # t1 = pd.Series(titanic[0])
# ----> 2 titanic[0]
#
# ...
